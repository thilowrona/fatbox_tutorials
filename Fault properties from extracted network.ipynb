# %%
import math
import numpy as np 
import networkx as nx
import pickle
import matplotlib.pyplot as plt

from fatbox.metrics import compute_edge_values
from fatbox.plots import plot_components, plot_edge_attribute, plot_rose

# %%
G = pickle.load(open(r'D:\PYTHON\fatbox\fatbox_tutorials\Numerical_models\2-fault_properties\g_27.p', 'rb'))

# %%
fig, ax = plt.subplots(figsize=(8,8))
plot_components(G, ax, label=True)
ax.axis('equal')
ax.set_xlabel('X-coordinate')
ax.set_ylabel('Y-coordinate')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 fig, ax = plt.subplots(figsize=(8,8))
# ----> 2 plot_components(G, ax, label=True)
#       3 ax.axis('equal')
#       4 ax.set_xlabel('X-coordinate')
#
# TypeError: plot_components() got multiple values for argument 'label'
