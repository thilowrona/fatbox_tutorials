# %%
import fatbox

# %%
import numpy as np 
import networkx as nx
import pickle
import cv2
from PIL import Image
from tqdm import tqdm

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import ListedColormap
from scipy.spatial import distance_matrix
from skimage import feature, morphology, filters
from sklearn.preprocessing import normalize

from sys import stdout

from fatbox.preprocessing import *
from fatbox.metrics import *
from fatbox.edits import *
from fatbox.plots import *

# %%
img = Image.open(r'D:\PYTHON\fatbox\fatbox_tutorials\Predicted_fault_data\Kerry_inline_14.png').convert('L')
data = np.array(img)

data = 1-(data-np.min(data))/(np.max(data)-np.min(data))

# %%
fig, ax = plt.subplots(figsize=(10,10))
im = ax.imshow(data, cmap='Greys', vmin=0)
plt.xticks([])
plt.yticks([])
plt.title('Kerry Inline 14')
divider = make_axes_locatable(ax)
cax = divider.new_vertical(size="10%", pad=0.2, pack_start=True)
fig.add_axes(cax)
fig.colorbar(im, cax=cax, orientation="horizontal")
plt.savefig('./Kerry Inline 14.png')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
smoothed = filters.gaussian(data, sigma=1.2)

fig, ax = plt.subplots(figsize=(10,10))
im = ax.imshow(smoothed, cmap='Greys', vmin=0)
plt.xticks([])
plt.yticks([])
plt.title('Kerry Inline 15')
divider = make_axes_locatable(ax)
cax = divider.new_vertical(size="5%", pad=0.2, pack_start=True)
fig.add_axes(cax)
fig.colorbar(im, cax=cax, orientation="horizontal")
plt.show()

# %%
threshold = simple_threshold_binary(smoothed, 0.8)

fig, ax = plt.subplots(figsize=(10,10))
im = ax.imshow(threshold, vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
plt.title('Kerry Inline 15 - Binerized')
divider = make_axes_locatable(ax)
cax = divider.new_vertical(size="5%", pad=0.2, pack_start=True)
fig.add_axes(cax)
fig.colorbar(im, cax=cax, orientation="horizontal")
plt.savefig('./Kerry Inline 15 - Binerized.png')
plt.show()

# %%
skeleton = skeleton_guo_hall(threshold)

fig, ax = plt.subplots(figsize=(10,10))
im = ax.imshow(skeleton, vmin=0, vmax=0.1)
plt.axis('off')
plt.title('Kerry Inline 14 - Skeletonized')
divider = make_axes_locatable(ax)
cax = divider.new_vertical(size="5%", pad=0.2, pack_start=True)
fig.add_axes(cax)
fig.colorbar(im, cax=cax, orientation="horizontal")
plt.show()
plt.savefig('./Kerry Inline 15 - Skeletonized.png')
print(type(skeleton))
# Out:
# <class 'numpy.ndarray'>

# %%
skeleton = remove_small_regions((skeleton), 8)
fig, ax = plt.subplots(figsize=(10,10))
im = ax.imshow(skeleton, vmin=0, vmax=0.1)
plt.axis('off')
plt.title('Kerry Inline 15')
divider = make_axes_locatable(ax)
cax = divider.new_vertical(size="5%", pad=0.2, pack_start=True)
fig.add_axes(cax)
fig.colorbar(im, cax=cax, orientation="horizontal")
plt.savefig('./Kerry Inline 14 - Removed Small Area.png')
plt.show()

# %%
ret, markers = cv2.connectedComponents(skeleton, connectivity=8)

fig, ax = plt.subplots(figsize=(10,10))
im = ax.imshow(markers, vmin=0, vmax=10)
plt.axis('off')
plt.title('Kerry Inline 15')
divider = make_axes_locatable(ax)
cax = divider.new_vertical(size="5%", pad=0.2, pack_start=True)
fig.add_axes(cax)
fig.colorbar(im, cax=cax, orientation="horizontal")
plt.savefig('./Kerry Inline 15 - Connected Components.png')
plt.show()

# %%
G = nx.Graph()

node = 0
for comp in tqdm(range(1,ret)):

    points = np.transpose(np.vstack((np.where(markers==comp))))    
    
    for point in points:
        G.add_node(node)
        G.nodes[node]['pos'] = (point[1], point[0])
        G.nodes[node]['component'] = comp
        node += 1
# Out:
# 100%|██████████| 40/40 [00:00<00:00, 919.91it/s]

# %%
for comp in tqdm(range(1,ret)): 
    
    points = [G.nodes[node]['pos'] for node in G if G.nodes[node]['component']==comp]
    nodes  = [node for node in G if G.nodes[node]['component']==comp]

    dm = distance_matrix(points, points)  
    
    
    for n in range(len(points)):
        # print(n)
        for m in range(len(points)):
            if dm[n,m]<1.5 and n != m:
                G.add_edge(nodes[n],nodes[m])
# Out:
# 100%|██████████| 40/40 [00:00<00:00, 139.10it/s]

# %%
G = label_components(G)

fig, ax = plt.subplots(1, 1, figsize=(15,15))
ax.imshow(np.zeros_like(data), 'gray_r', vmin=0)
plt.title('Kerry Inline 14 - Skeletonized Fault')
plot_components(G, label=False, node_size=1, ax=ax)
# plot_faults(G, label=True, node_size=1, ax=ax)
ax.set_xlim(0,data.shape[1])
ax.set_ylim(data.shape[0],0)
plt.show()

# %%
G = split_triple_junctions(G, 25)
G = label_components(G)

# %%
removed = [1, 34, 50, 17, 3, 45, 25]
for i in removed:
    G = remove_component(G, i)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15,15))
ax.imshow(np.zeros_like(data), 'gray_r', vmin=0)
plot_components(G, label=True, node_size=1, ax=ax)
plt.title('Kerry Inline 15 - Labeled Fault')
ax.axis('on')
ax.set_xlim(0,data.shape[1])
ax.set_ylim(data.shape[0],0)
plt.savefig('./Kerry Inline 15 - Labeled Predicted Fault.png')
plt.show()

# %%
G = label_components(G)
G = compute_edge_length(G)
G = calculate_strike(G, 3)
G = comp_to_fault(G)
# H = expand_network(G)
# Out:
# Calculate strike: 100%|██████████| 3179/3179 [00:00<00:00, 64829.26it/s]

# %%
top = cm.get_cmap('Oranges_r', 128) # r means reversed version
bottom = cm.get_cmap('Blues', 128)# combine it all
newcolors = np.vstack((top(np.linspace(0, 1, 128)),
                       bottom(np.linspace(0, 1, 128))))# create a new colormaps with a name of OrangeBlue
orange_blue = ListedColormap(newcolors, name='OrangeBlue')


fig, ax = plt.subplots(1, 1, figsize=(15, 15))
ax.imshow(data, cmap='Greys', vmin=0, vmax=1)
plot_attribute(G, 'strike', cmap = orange_blue, vmin=0, vmax=180, ax=ax)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_24440\1484380427.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   top = cm.get_cmap('Oranges_r', 128) # r means reversed version
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_24440\1484380427.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   bottom = cm.get_cmap('Blues', 128)# combine it all

# %%
plot_rose(G)

# %%
import networkx as nx; 
from networkx.readwrite import json_graph;

# %%
import json
json_G = json_graph.node_link_data(G)
json_G
# Out:
# {'directed': False,
#  'multigraph': False,
#  'graph': {},
#  'nodes': [{'pos': (270, 0),
#    'component': 0,
#    'strike': 0.0,
#    'fault': 0,
#    'id': 0},
#   {'pos': (270, 1),
#    'component': 0,
#    'strike': 14.036243467926479,
#    'fault': 0,
#    'id': 1},
#   {'pos': (270, 2),
#    'component': 0,
#    'strike': 11.309932474020213,
#    'fault': 0,
#    'id': 2},
#   {'pos': (270, 3),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 3},
#   {'pos': (271, 4),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 4},
#   {'pos': (271, 5),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 5},
#   {'pos': (271, 6),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 6},
#   {'pos': (271, 7),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 7},
#   {'pos': (271, 8),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 8},
#   {'pos': (271, 9),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 9},
#   {'pos': (272, 10),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 10},
#   {'pos': (272, 11),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 11},
#   {'pos': (272, 12),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 12},
#   {'pos': (272, 13),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 13},
#   {'pos': (272, 14),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 14},
#   {'pos': (272, 15),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 15},
#   {'pos': (273, 16),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 16},
#   {'pos': (273, 17),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 17},
#   {'pos': (273, 18),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 18},
#   {'pos': (273, 19),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 19},
#   {'pos': (273, 20),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 20},
#   {'pos': (273, 21), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 21},
#   {'pos': (274, 22), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 22},
#   {'pos': (274, 23), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 23},
#   {'pos': (273, 24), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 24},
#   {'pos': (273, 25),
#    'component': 0,
#    'strike': 170.53767779197437,
#    'fault': 0,
#    'id': 25},
#   {'pos': (273, 26),
#    'component': 0,
#    'strike': 170.53767779197437,
#    'fault': 0,
#    'id': 26},
#   {'pos': (273, 27), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 27},
#   {'pos': (273, 28), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 28},
#   {'pos': (273, 29), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 29},
#   {'pos': (273, 30), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 30},
#   {'pos': (273, 31), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 31},
#   {'pos': (273, 32), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 32},
#   {'pos': (273, 33), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 33},
#   {'pos': (273, 34), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 34},
#   {'pos': (273, 35), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 35},
#   {'pos': (273, 36), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 36},
#   {'pos': (273, 37), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 37},
#   {'pos': (273, 38), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 38},
#   {'pos': (273, 39),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 39},
#   {'pos': (273, 40), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 40},
#   {'pos': (273, 41), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 41},
#   {'pos': (274, 42), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 42},
#   {'pos': (273, 43), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 43},
#   {'pos': (273, 44), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 44},
#   {'pos': (273, 45),
#    'component': 0,
#    'strike': 170.53767779197437,
#    'fault': 0,
#    'id': 45},
#   {'pos': (273, 46), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 46},
#   {'pos': (273, 47), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 47},
#   {'pos': (273, 48), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 48},
#   {'pos': (273, 49), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 49},
#   {'pos': (273, 50), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 50},
#   {'pos': (273, 51), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 51},
#   {'pos': (273, 52), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 52},
#   {'pos': (273, 53), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 53},
#   {'pos': (273, 54), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 54},
#   {'pos': (273, 55), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 55},
#   {'pos': (273, 56),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 56},
#   {'pos': (273, 57),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 57},
#   {'pos': (273, 58),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 58},
#   {'pos': (274, 59),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 59},
#   {'pos': (274, 60),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 60},
#   {'pos': (274, 61),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 61},
#   {'pos': (274, 62), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 62},
#   {'pos': (274, 63), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 63},
#   {'pos': (274, 64), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 64},
#   {'pos': (274, 65), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 65},
#   {'pos': (274, 66), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 66},
#   {'pos': (274, 67), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 67},
#   {'pos': (274, 68), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 68},
#   {'pos': (274, 69), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 69},
#   {'pos': (274, 70), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 70},
#   {'pos': (274, 71), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 71},
#   {'pos': (274, 72), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 72},
#   {'pos': (274, 73),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 73},
#   {'pos': (274, 74),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 74},
#   {'pos': (274, 75),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 75},
#   {'pos': (275, 76),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 76},
#   {'pos': (275, 77),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 77},
#   {'pos': (275, 78),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 78},
#   {'pos': (275, 79),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 79},
#   {'pos': (275, 80),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 80},
#   {'pos': (275, 81),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 81},
#   {'pos': (276, 82),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 82},
#   {'pos': (276, 83),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 83},
#   {'pos': (276, 84), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 84},
#   {'pos': (276, 85),
#    'component': 0,
#    'strike': 170.53767779197437,
#    'fault': 0,
#    'id': 85},
#   {'pos': (276, 86),
#    'component': 0,
#    'strike': 170.53767779197437,
#    'fault': 0,
#    'id': 86},
#   {'pos': (275, 87),
#    'component': 0,
#    'strike': 170.53767779197437,
#    'fault': 0,
#    'id': 87},
#   {'pos': (275, 88),
#    'component': 0,
#    'strike': 170.53767779197437,
#    'fault': 0,
#    'id': 88},
#   {'pos': (275, 89),
#    'component': 0,
#    'strike': 170.53767779197437,
#    'fault': 0,
#    'id': 89},
#   {'pos': (275, 90), 'component': 0, 'strike': 0.0, 'fault': 0, 'id': 90},
#   {'pos': (275, 91),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 91},
#   {'pos': (275, 92),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 92},
#   {'pos': (275, 93),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 93},
#   {'pos': (276, 94),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 94},
#   {'pos': (276, 95),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 95},
#   {'pos': (276, 96),
#    'component': 0,
#    'strike': 18.43494882292201,
#    'fault': 0,
#    'id': 96},
#   {'pos': (276, 97),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 97},
#   {'pos': (276, 98),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 98},
#   {'pos': (277, 99),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 99},
#   {'pos': (277, 100),
#    'component': 0,
#    'strike': 18.43494882292201,
#    'fault': 0,
#    'id': 100},
#   {'pos': (277, 101),
#    'component': 0,
#    'strike': 18.43494882292201,
#    'fault': 0,
#    'id': 101},
#   {'pos': (277, 102),
#    'component': 0,
#    'strike': 9.462322208025617,
#    'fault': 0,
#    'id': 102},
#   {'pos': (278, 103),
#    'component': 0,
#    'strike': 11.309932474020213,
#    'fault': 0,
#    'id': 103},
#   {'pos': (278, 104),
#    'component': 0,
#    'strike': 14.036243467926479,
#    'fault': 0,
#    'id': 104},
#   {'pos': (278, 105),
#    'component': 0,
#    'strike': 18.43494882292201,
#    'fault': 0,
#    'id': 105},
#   {'pos': (278, 107),
#    'component': 1,
#    'strike': 146.30993247402023,
#    'fault': 1,
#    'id': 107},
#   {'pos': (279, 107), 'component': 1, 'strike': 45.0, 'fault': 1, 'id': 108},
#   {'pos': (277, 108),
#    'component': 1,
#    'strike': 153.43494882292202,
#    'fault': 1,
#    'id': 109},
#   {'pos': (280, 108),
#    'component': 1,
#    'strike': 36.86989764584402,
#    'fault': 1,
#    'id': 110},
#   {'pos': (277, 109),
#    'component': 1,
#    'strike': 158.19859051364818,
#    'fault': 1,
#    'id': 111},
#   {'pos': (280, 109),
#    'component': 1,
#    'strike': 30.96375653207352,
#    'fault': 1,
#    'id': 112},
#   {'pos': (276, 110),
#    'component': 1,
#    'strike': 161.56505117707798,
#    'fault': 1,
#    'id': 113},
#   {'pos': (281, 110),
#    'component': 1,
#    'strike': 18.43494882292201,
#    'fault': 1,
#    'id': 114},
#   {'pos': (276, 111),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 115},
#   {'pos': (281, 111),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 116},
#   {'pos': (276, 112),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 117},
#   {'pos': (281, 112),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 118},
#   {'pos': (276, 113), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 119},
#   {'pos': (281, 113), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 120},
#   {'pos': (276, 114), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 121},
#   {'pos': (281, 114), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 122},
#   {'pos': (276, 115), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 123},
#   {'pos': (281, 115), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 124},
#   {'pos': (276, 116),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 125},
#   {'pos': (281, 116),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 126},
#   {'pos': (276, 117),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 127},
#   {'pos': (281, 117),
#    'component': 1,
#    'strike': 161.56505117707798,
#    'fault': 1,
#    'id': 128},
#   {'pos': (276, 118),
#    'component': 1,
#    'strike': 18.43494882292201,
#    'fault': 1,
#    'id': 129},
#   {'pos': (281, 118),
#    'component': 1,
#    'strike': 158.19859051364818,
#    'fault': 1,
#    'id': 130},
#   {'pos': (277, 119),
#    'component': 1,
#    'strike': 18.43494882292201,
#    'fault': 1,
#    'id': 131},
#   {'pos': (280, 119),
#    'component': 1,
#    'strike': 153.43494882292202,
#    'fault': 1,
#    'id': 132},
#   {'pos': (277, 120),
#    'component': 1,
#    'strike': 18.43494882292201,
#    'fault': 1,
#    'id': 133},
#   {'pos': (279, 120),
#    'component': 1,
#    'strike': 146.30993247402023,
#    'fault': 1,
#    'id': 134},
#   {'pos': (278, 121),
#    'component': 1,
#    'strike': 18.43494882292201,
#    'fault': 1,
#    'id': 135},
#   {'pos': (278, 122),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 136},
#   {'pos': (278, 123), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 137},
#   {'pos': (278, 124),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 138},
#   {'pos': (278, 125),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 139},
#   {'pos': (277, 126),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 140},
#   {'pos': (277, 127),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 141},
#   {'pos': (277, 128),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 142},
#   {'pos': (277, 129), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 143},
#   {'pos': (277, 130), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 144},
#   {'pos': (277, 131), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 145},
#   {'pos': (277, 132), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 146},
#   {'pos': (277, 133), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 147},
#   {'pos': (277, 134), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 148},
#   {'pos': (277, 135), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 149},
#   {'pos': (277, 136), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 150},
#   {'pos': (277, 137), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 151},
#   {'pos': (277, 138), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 152},
#   {'pos': (277, 139), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 153},
#   {'pos': (277, 140), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 154},
#   {'pos': (277, 141), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 155},
#   {'pos': (277, 142), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 156},
#   {'pos': (277, 143), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 157},
#   {'pos': (277, 144), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 158},
#   {'pos': (277, 145), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 159},
#   {'pos': (277, 146), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 160},
#   {'pos': (277, 147), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 161},
#   {'pos': (277, 148), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 162},
#   {'pos': (277, 149), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 163},
#   {'pos': (277, 150), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 164},
#   {'pos': (277, 151), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 165},
#   {'pos': (277, 152), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 166},
#   {'pos': (277, 153), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 167},
#   {'pos': (277, 154), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 168},
#   {'pos': (277, 155), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 169},
#   {'pos': (277, 156), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 170},
#   {'pos': (277, 157), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 171},
#   {'pos': (277, 158), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 172},
#   {'pos': (277, 159), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 173},
#   {'pos': (277, 160), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 174},
#   {'pos': (277, 161), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 175},
#   {'pos': (277, 162), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 176},
#   {'pos': (277, 163),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 177},
#   {'pos': (277, 164),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 178},
#   {'pos': (277, 165),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 179},
#   {'pos': (278, 166), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 180},
#   {'pos': (278, 167), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 181},
#   {'pos': (278, 168), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 182},
#   {'pos': (277, 169),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 183},
#   {'pos': (277, 170),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 184},
#   {'pos': (277, 171),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 185},
#   {'pos': (277, 172), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 186},
#   {'pos': (277, 173), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 187},
#   {'pos': (277, 174), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 188},
#   {'pos': (277, 175), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 189},
#   {'pos': (277, 176), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 190},
#   {'pos': (277, 177), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 191},
#   {'pos': (277, 178), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 192},
#   {'pos': (277, 179), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 193},
#   {'pos': (277, 180), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 194},
#   {'pos': (277, 181), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 195},
#   {'pos': (277, 182), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 196},
#   {'pos': (277, 183), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 197},
#   {'pos': (277, 184), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 198},
#   {'pos': (277, 185), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 199},
#   {'pos': (277, 186), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 200},
#   {'pos': (277, 187), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 201},
#   {'pos': (277, 188), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 202},
#   {'pos': (277, 189), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 203},
#   {'pos': (277, 190),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 204},
#   {'pos': (277, 191),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 205},
#   {'pos': (277, 192),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 206},
#   {'pos': (278, 193), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 207},
#   {'pos': (278, 194), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 208},
#   {'pos': (278, 195), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 209},
#   {'pos': (277, 196),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 210},
#   {'pos': (277, 197),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 211},
#   {'pos': (277, 198),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 212},
#   {'pos': (277, 199),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 213},
#   {'pos': (277, 200),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 214},
#   {'pos': (277, 201),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 215},
#   {'pos': (278, 202),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 216},
#   {'pos': (278, 203),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 217},
#   {'pos': (278, 204),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 218},
#   {'pos': (278, 205), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 219},
#   {'pos': (278, 206), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 220},
#   {'pos': (278, 207), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 221},
#   {'pos': (278, 208), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 222},
#   {'pos': (278, 209), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 223},
#   {'pos': (278, 210), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 224},
#   {'pos': (278, 211), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 225},
#   {'pos': (278, 212), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 226},
#   {'pos': (278, 213), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 227},
#   {'pos': (278, 214), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 228},
#   {'pos': (278, 215), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 229},
#   {'pos': (278, 216), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 230},
#   {'pos': (278, 217), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 231},
#   {'pos': (278, 218), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 232},
#   {'pos': (278, 219),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 233},
#   {'pos': (278, 220),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 234},
#   {'pos': (278, 221),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 235},
#   {'pos': (279, 222),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 236},
#   {'pos': (279, 223),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 237},
#   {'pos': (279, 224),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 238},
#   {'pos': (279, 225), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 239},
#   {'pos': (279, 226), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 240},
#   {'pos': (279, 227), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 241},
#   {'pos': (279, 228), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 242},
#   {'pos': (279, 229), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 243},
#   {'pos': (279, 230), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 244},
#   {'pos': (279, 231), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 245},
#   {'pos': (279, 232), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 246},
#   {'pos': (279, 233), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 247},
#   {'pos': (279, 234), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 248},
#   {'pos': (279, 235),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 249},
#   {'pos': (279, 236),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 250},
#   {'pos': (279, 237),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 251},
#   {'pos': (278, 238),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 252},
#   {'pos': (278, 239),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 253},
#   {'pos': (278, 240),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 254},
#   {'pos': (278, 241), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 255},
#   {'pos': (278, 242), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 256},
#   {'pos': (278, 243),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 257},
#   {'pos': (278, 244),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 258},
#   {'pos': (278, 245),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 259},
#   {'pos': (279, 246),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 260},
#   {'pos': (279, 247),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 261},
#   {'pos': (279, 248),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 262},
#   {'pos': (279, 249),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 263},
#   {'pos': (279, 250),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 264},
#   {'pos': (279, 251),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 265},
#   {'pos': (280, 252),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 266},
#   {'pos': (280, 253),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 267},
#   {'pos': (280, 254),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 268},
#   {'pos': (280, 255),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 269},
#   {'pos': (280, 256),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 270},
#   {'pos': (280, 257),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 271},
#   {'pos': (279, 258),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 272},
#   {'pos': (279, 259),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 273},
#   {'pos': (279, 260),
#    'component': 1,
#    'strike': 170.53767779197437,
#    'fault': 1,
#    'id': 274},
#   {'pos': (279, 261), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 275},
#   {'pos': (279, 262), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 276},
#   {'pos': (279, 263), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 277},
#   {'pos': (279, 264),
#    'component': 1,
#    'strike': 9.462322208025617,
#    'fault': 1,
#    'id': 278},
#   {'pos': (279, 265),
#    'component': 1,
#    'strike': 18.43494882292201,
#    'fault': 1,
#    'id': 279},
#   {'pos': (279, 266),
#    'component': 1,
#    'strike': 18.43494882292201,
#    'fault': 1,
#    'id': 280},
#   {'pos': (280, 267),
#    'component': 1,
#    'strike': 18.43494882292201,
#    'fault': 1,
#    'id': 282},
#   {'pos': (281, 268),
#    'component': 1,
#    'strike': 18.43494882292201,
#    'fault': 1,
#    'id': 284},
#   {'pos': (281, 269),
#    'component': 1,
#    'strike': 21.80140948635181,
#    'fault': 1,
#    'id': 286},
#   {'pos': (281, 270),
#    'component': 1,
#    'strike': 14.036243467926479,
#    'fault': 1,
#    'id': 288},
#   {'pos': (281, 271), 'component': 1, 'strike': 0.0, 'fault': 1, 'id': 290},
#   {'pos': (302, 0),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 291},
#   {'pos': (302, 1),
#    'component': 2,
#    'strike': 14.036243467926479,
#    'fault': 2,
#    'id': 292},
#   {'pos': (302, 2),
#    'component': 2,
#    'strike': 21.80140948635181,
#    'fault': 2,
#    'id': 293},
#   {'pos': (303, 3),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 294},
#   {'pos': (303, 4),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 295},
#   {'pos': (304, 5),
#    'component': 2,
#    'strike': 26.56505117707799,
#    'fault': 2,
#    'id': 296},
#   {'pos': (304, 6),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 297},
#   {'pos': (304, 7),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 298},
#   {'pos': (305, 8),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 299},
#   {'pos': (305, 9),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 300},
#   {'pos': (305, 10),
#    'component': 2,
#    'strike': 26.56505117707799,
#    'fault': 2,
#    'id': 301},
#   {'pos': (306, 11),
#    'component': 2,
#    'strike': 26.56505117707799,
#    'fault': 2,
#    'id': 302},
#   {'pos': (306, 12),
#    'component': 2,
#    'strike': 26.56505117707799,
#    'fault': 2,
#    'id': 303},
#   {'pos': (307, 13),
#    'component': 2,
#    'strike': 33.690067525979785,
#    'fault': 2,
#    'id': 304},
#   {'pos': (308, 14),
#    'component': 2,
#    'strike': 26.56505117707799,
#    'fault': 2,
#    'id': 305},
#   {'pos': (308, 15),
#    'component': 2,
#    'strike': 26.56505117707799,
#    'fault': 2,
#    'id': 306},
#   {'pos': (309, 16),
#    'component': 2,
#    'strike': 26.56505117707799,
#    'fault': 2,
#    'id': 307},
#   {'pos': (309, 17),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 308},
#   {'pos': (309, 18),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 309},
#   {'pos': (310, 19),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 310},
#   {'pos': (310, 20),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 311},
#   {'pos': (310, 21),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 312},
#   {'pos': (311, 22),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 313},
#   {'pos': (311, 23),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 314},
#   {'pos': (311, 24),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 315},
#   {'pos': (311, 25),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 316},
#   {'pos': (311, 26),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 317},
#   {'pos': (311, 27),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 318},
#   {'pos': (312, 28),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 319},
#   {'pos': (312, 29),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 320},
#   {'pos': (313, 30),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 321},
#   {'pos': (313, 31),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 322},
#   {'pos': (313, 32),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 323},
#   {'pos': (313, 33),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 324},
#   {'pos': (314, 34),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 325},
#   {'pos': (314, 35),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 326},
#   {'pos': (314, 36),
#    'component': 2,
#    'strike': 18.43494882292201,
#    'fault': 2,
#    'id': 327},
#   {'pos': (315, 37),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 328},
#   {'pos': (315, 38),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 329},
#   {'pos': (315, 39),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 330},
#   {'pos': (315, 40),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 331},
#   {'pos': (315, 41),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 332},
#   {'pos': (315, 42),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 333},
#   {'pos': (316, 43),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 334},
#   {'pos': (316, 44),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 335},
#   {'pos': (316, 45),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 336},
#   {'pos': (316, 46), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 337},
#   {'pos': (316, 47),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 338},
#   {'pos': (316, 48),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 339},
#   {'pos': (316, 49),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 340},
#   {'pos': (317, 50),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 341},
#   {'pos': (317, 51),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 342},
#   {'pos': (317, 52),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 343},
#   {'pos': (317, 53), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 344},
#   {'pos': (317, 54), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 345},
#   {'pos': (317, 55), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 346},
#   {'pos': (317, 56),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 347},
#   {'pos': (317, 57),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 348},
#   {'pos': (317, 58),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 349},
#   {'pos': (318, 59),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 350},
#   {'pos': (318, 60),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 351},
#   {'pos': (318, 61),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 352},
#   {'pos': (318, 62), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 353},
#   {'pos': (318, 63), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 354},
#   {'pos': (318, 64),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 355},
#   {'pos': (318, 65),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 356},
#   {'pos': (318, 66),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 357},
#   {'pos': (319, 67),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 358},
#   {'pos': (319, 68),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 359},
#   {'pos': (319, 69),
#    'component': 2,
#    'strike': 9.462322208025617,
#    'fault': 2,
#    'id': 360},
#   {'pos': (319, 70), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 361},
#   {'pos': (319, 71), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 362},
#   {'pos': (319, 72), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 363},
#   {'pos': (319, 73), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 364},
#   {'pos': (319, 74), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 365},
#   {'pos': (319, 75), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 366},
#   {'pos': (319, 76), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 367},
#   {'pos': (319, 77), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 368},
#   {'pos': (319, 78), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 369},
#   {'pos': (319, 79), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 370},
#   {'pos': (319, 80), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 371},
#   {'pos': (319, 81),
#    'component': 2,
#    'strike': 170.53767779197437,
#    'fault': 2,
#    'id': 372},
#   {'pos': (319, 82),
#    'component': 2,
#    'strike': 170.53767779197437,
#    'fault': 2,
#    'id': 373},
#   {'pos': (319, 83),
#    'component': 2,
#    'strike': 170.53767779197437,
#    'fault': 2,
#    'id': 374},
#   {'pos': (318, 84),
#    'component': 2,
#    'strike': 170.53767779197437,
#    'fault': 2,
#    'id': 375},
#   {'pos': (318, 85), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 376},
#   {'pos': (318, 86),
#    'component': 2,
#    'strike': 170.53767779197437,
#    'fault': 2,
#    'id': 377},
#   {'pos': (318, 87), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 378},
#   {'pos': (319, 88), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 379},
#   {'pos': (318, 89), 'component': 2, 'strike': 0.0, 'fault': 2, 'id': 380},
#   {'pos': (404, 0), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 381},
#   {'pos': (404, 1),
#    'component': 3,
#    'strike': 165.96375653207355,
#    'fault': 3,
#    'id': 382},
#   {'pos': (404, 2),
#    'component': 3,
#    'strike': 168.69006752597977,
#    'fault': 3,
#    'id': 383},
#   {'pos': (404, 3),
#    'component': 3,
#    'strike': 170.53767779197437,
#    'fault': 3,
#    'id': 384},
#   {'pos': (403, 4),
#    'component': 3,
#    'strike': 170.53767779197437,
#    'fault': 3,
#    'id': 385},
#   {'pos': (403, 5),
#    'component': 3,
#    'strike': 170.53767779197437,
#    'fault': 3,
#    'id': 386},
#   {'pos': (403, 6), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 387},
#   {'pos': (403, 7),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 388},
#   {'pos': (403, 8),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 389},
#   {'pos': (404, 9),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 390},
#   {'pos': (404, 10),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 391},
#   {'pos': (404, 11),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 392},
#   {'pos': (404, 12), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 393},
#   {'pos': (404, 13), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 394},
#   {'pos': (404, 14),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 395},
#   {'pos': (404, 15), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 396},
#   {'pos': (404, 16), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 397},
#   {'pos': (405, 17), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 398},
#   {'pos': (404, 18),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 399},
#   {'pos': (404, 19),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 400},
#   {'pos': (404, 20), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 401},
#   {'pos': (405, 21),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 402},
#   {'pos': (405, 22),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 403},
#   {'pos': (405, 23),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 404},
#   {'pos': (405, 24),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 405},
#   {'pos': (405, 25),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 406},
#   {'pos': (405, 26),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 407},
#   {'pos': (406, 27),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 408},
#   {'pos': (406, 28),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 409},
#   {'pos': (406, 29),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 410},
#   {'pos': (406, 30), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 411},
#   {'pos': (406, 31), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 412},
#   {'pos': (406, 32), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 413},
#   {'pos': (406, 33), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 414},
#   {'pos': (406, 34), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 415},
#   {'pos': (406, 35),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 416},
#   {'pos': (406, 36),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 417},
#   {'pos': (406, 37),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 418},
#   {'pos': (407, 38),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 419},
#   {'pos': (407, 39),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 420},
#   {'pos': (407, 40),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 421},
#   {'pos': (407, 41), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 422},
#   {'pos': (407, 42), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 423},
#   {'pos': (407, 43), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 424},
#   {'pos': (407, 44), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 425},
#   {'pos': (407, 45), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 426},
#   {'pos': (407, 46), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 427},
#   {'pos': (407, 47), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 428},
#   {'pos': (407, 48), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 429},
#   {'pos': (407, 49), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 430},
#   {'pos': (407, 50), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 431},
#   {'pos': (407, 51), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 432},
#   {'pos': (407, 52), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 433},
#   {'pos': (407, 53), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 434},
#   {'pos': (407, 54),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 435},
#   {'pos': (407, 55),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 436},
#   {'pos': (407, 56),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 437},
#   {'pos': (408, 57),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 438},
#   {'pos': (408, 58),
#    'component': 3,
#    'strike': 18.43494882292201,
#    'fault': 3,
#    'id': 439},
#   {'pos': (408, 59),
#    'component': 3,
#    'strike': 18.43494882292201,
#    'fault': 3,
#    'id': 440},
#   {'pos': (408, 60),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 441},
#   {'pos': (409, 61),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 442},
#   {'pos': (409, 62),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 443},
#   {'pos': (409, 63),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 444},
#   {'pos': (409, 64),
#    'component': 3,
#    'strike': 9.462322208025617,
#    'fault': 3,
#    'id': 445},
#   {'pos': (409, 65), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 446},
#   {'pos': (409, 66), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 447},
#   {'pos': (410, 67), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 448},
#   {'pos': (409, 68), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 449},
#   {'pos': (409, 69), 'component': 3, 'strike': 0.0, 'fault': 3, 'id': 450},
#   {'pos': (427, 0),
#    'component': 4,
#    'strike': 18.43494882292201,
#    'fault': 4,
#    'id': 451},
#   {'pos': (427, 1),
#    'component': 4,
#    'strike': 14.036243467926479,
#    'fault': 4,
#    'id': 452},
#   {'pos': (427, 2),
#    'component': 4,
#    'strike': 11.309932474020213,
#    'fault': 4,
#    'id': 453},
#   {'pos': (428, 3), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 454},
#   {'pos': (428, 4), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 455},
#   {'pos': (428, 5), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 456},
#   {'pos': (427, 6),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 457},
#   {'pos': (427, 7),
#    'component': 4,
#    'strike': 161.56505117707798,
#    'fault': 4,
#    'id': 458},
#   {'pos': (427, 8),
#    'component': 4,
#    'strike': 161.56505117707798,
#    'fault': 4,
#    'id': 459},
#   {'pos': (427, 9),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 460},
#   {'pos': (426, 10),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 461},
#   {'pos': (426, 11),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 462},
#   {'pos': (426, 12),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 463},
#   {'pos': (426, 13), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 464},
#   {'pos': (426, 14), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 465},
#   {'pos': (426, 15), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 466},
#   {'pos': (426, 16), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 467},
#   {'pos': (426, 17), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 468},
#   {'pos': (426, 18),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 469},
#   {'pos': (426, 19),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 470},
#   {'pos': (426, 20),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 471},
#   {'pos': (425, 21),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 472},
#   {'pos': (425, 22),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 473},
#   {'pos': (425, 23),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 474},
#   {'pos': (425, 24), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 475},
#   {'pos': (425, 25), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 476},
#   {'pos': (425, 26), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 477},
#   {'pos': (425, 27),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 478},
#   {'pos': (425, 28),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 479},
#   {'pos': (425, 29),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 480},
#   {'pos': (424, 30),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 481},
#   {'pos': (424, 31),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 482},
#   {'pos': (424, 32),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 483},
#   {'pos': (424, 33), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 484},
#   {'pos': (424, 34), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 485},
#   {'pos': (424, 35), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 486},
#   {'pos': (424, 36), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 487},
#   {'pos': (424, 37),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 488},
#   {'pos': (424, 38),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 489},
#   {'pos': (424, 39),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 490},
#   {'pos': (423, 40),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 491},
#   {'pos': (423, 41),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 492},
#   {'pos': (423, 42),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 493},
#   {'pos': (423, 43), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 494},
#   {'pos': (423, 44), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 495},
#   {'pos': (423, 45), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 496},
#   {'pos': (423, 46),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 497},
#   {'pos': (423, 47),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 498},
#   {'pos': (423, 48), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 499},
#   {'pos': (422, 49), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 500},
#   {'pos': (422, 50),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 501},
#   {'pos': (423, 51),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 502},
#   {'pos': (423, 52), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 503},
#   {'pos': (422, 53), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 504},
#   {'pos': (422, 54),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 505},
#   {'pos': (422, 55),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 506},
#   {'pos': (422, 56), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 507},
#   {'pos': (422, 57), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 508},
#   {'pos': (422, 58), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 509},
#   {'pos': (422, 59),
#    'component': 4,
#    'strike': 9.462322208025617,
#    'fault': 4,
#    'id': 510},
#   {'pos': (422, 60), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 511},
#   {'pos': (422, 61), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 512},
#   {'pos': (423, 62), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 513},
#   {'pos': (422, 63), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 514},
#   {'pos': (422, 64), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 515},
#   {'pos': (422, 65),
#    'component': 4,
#    'strike': 170.53767779197437,
#    'fault': 4,
#    'id': 516},
#   {'pos': (422, 66), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 517},
#   {'pos': (422, 67), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 518},
#   {'pos': (422, 68), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 519},
#   {'pos': (422, 69), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 520},
#   {'pos': (422, 70), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 521},
#   {'pos': (422, 71), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 522},
#   {'pos': (422, 72), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 523},
#   {'pos': (422, 73), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 524},
#   {'pos': (422, 74), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 525},
#   {'pos': (422, 75), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 526},
#   {'pos': (422, 76), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 527},
#   {'pos': (422, 77), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 528},
#   {'pos': (422, 78), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 529},
#   {'pos': (422, 79), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 530},
#   {'pos': (422, 80), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 531},
#   {'pos': (422, 81), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 532},
#   {'pos': (422, 82), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 533},
#   {'pos': (422, 83), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 534},
#   {'pos': (422, 84), 'component': 4, 'strike': 0.0, 'fault': 4, 'id': 535},
# ...
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 794, 'target': 795},
#   {'length': 1.0, 'strike': 0.0, 'source': 795, 'target': 796},
#   {'length': 1.0, 'strike': 0.0, 'source': 796, 'target': 797},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 797, 'target': 798},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 798, 'target': 799},
#   {'length': 1.4142135623730951,
#    'strike': 170.53767779197437,
#    'source': 799,
#    'target': 800},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 800, 'target': 801},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 801, 'target': 802},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 802, 'target': 803},
#   {'length': 1.0, 'strike': 0.0, 'source': 803, 'target': 804},
#   {'length': 1.0, 'strike': 0.0, 'source': 804, 'target': 805},
#   {'length': 1.0, 'strike': 0.0, 'source': 805, 'target': 806},
#   {'length': 1.0, 'strike': 0.0, 'source': 806, 'target': 807},
#   {'length': 1.0, 'strike': 0.0, 'source': 807, 'target': 808},
#   {'length': 1.0, 'strike': 0.0, 'source': 808, 'target': 809},
#   {'length': 1.0, 'strike': 0.0, 'source': 809, 'target': 810},
#   {'length': 1.0, 'strike': 0.0, 'source': 810, 'target': 811},
#   {'length': 1.0, 'strike': 0.0, 'source': 811, 'target': 812},
#   {'length': 1.0, 'strike': 0.0, 'source': 812, 'target': 813},
#   {'length': 1.0, 'strike': 0.0, 'source': 813, 'target': 814},
#   {'length': 1.0, 'strike': 0.0, 'source': 814, 'target': 815},
#   {'length': 1.0, 'strike': 0.0, 'source': 815, 'target': 816},
#   {'length': 1.0, 'strike': 0.0, 'source': 816, 'target': 817},
#   {'length': 1.0, 'strike': 0.0, 'source': 817, 'target': 818},
#   {'length': 1.0, 'strike': 0.0, 'source': 818, 'target': 819},
#   {'length': 1.0, 'strike': 0.0, 'source': 819, 'target': 820},
#   {'length': 1.0, 'strike': 0.0, 'source': 820, 'target': 821},
#   {'length': 1.0, 'strike': 0.0, 'source': 821, 'target': 822},
#   {'length': 1.0, 'strike': 0.0, 'source': 822, 'target': 823},
#   {'length': 1.0, 'strike': 0.0, 'source': 823, 'target': 824},
#   {'length': 1.0, 'strike': 0.0, 'source': 824, 'target': 825},
#   {'length': 1.0, 'strike': 0.0, 'source': 825, 'target': 826},
#   {'length': 1.0, 'strike': 0.0, 'source': 826, 'target': 827},
#   {'length': 1.0, 'strike': 0.0, 'source': 827, 'target': 828},
#   {'length': 1.0, 'strike': 0.0, 'source': 828, 'target': 829},
#   {'length': 1.0, 'strike': 0.0, 'source': 829, 'target': 830},
#   {'length': 1.0, 'strike': 0.0, 'source': 830, 'target': 831},
#   {'length': 1.0, 'strike': 0.0, 'source': 831, 'target': 832},
#   {'length': 1.0, 'strike': 0.0, 'source': 832, 'target': 833},
#   {'length': 1.0, 'strike': 0.0, 'source': 833, 'target': 834},
#   {'length': 1.0, 'strike': 0.0, 'source': 834, 'target': 835},
#   {'length': 1.0, 'strike': 0.0, 'source': 835, 'target': 836},
#   {'length': 1.0, 'strike': 0.0, 'source': 836, 'target': 837},
#   {'length': 1.0, 'strike': 0.0, 'source': 837, 'target': 838},
#   {'length': 1.0, 'strike': 0.0, 'source': 838, 'target': 839},
#   {'length': 1.0, 'strike': 0.0, 'source': 839, 'target': 840},
#   {'length': 1.0, 'strike': 0.0, 'source': 840, 'target': 841},
#   {'length': 1.0, 'strike': 0.0, 'source': 841, 'target': 842},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 842, 'target': 843},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 843, 'target': 844},
#   {'length': 1.4142135623730951,
#    'strike': 9.462322208025617,
#    'source': 844,
#    'target': 845},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 845, 'target': 846},
#   {'length': 1.0, 'strike': 11.309932474020213, 'source': 846, 'target': 847},
#   {'length': 1.0, 'strike': 14.036243467926479, 'source': 847, 'target': 848},
#   {'length': 1.4142135623730951,
#    'strike': 33.690067525979785,
#    'source': 849,
#    'target': 850},
#   {'length': 1.4142135623730951,
#    'strike': 33.690067525979785,
#    'source': 849,
#    'target': 851},
#   {'length': 1.4142135623730951,
#    'strike': 143.13010235415595,
#    'source': 850,
#    'target': 852},
#   {'length': 1.0, 'strike': 26.56505117707799, 'source': 851, 'target': 853},
#   {'length': 1.4142135623730951,
#    'strike': 141.34019174590992,
#    'source': 852,
#    'target': 854},
#   {'length': 1.4142135623730951,
#    'strike': 21.80140948635181,
#    'source': 853,
#    'target': 855},
#   {'length': 1.0, 'strike': 146.30993247402023, 'source': 854, 'target': 856},
#   {'length': 1.0, 'strike': 26.56505117707799, 'source': 855, 'target': 857},
#   {'length': 1.4142135623730951,
#    'strike': 153.43494882292202,
#    'source': 856,
#    'target': 858},
#   {'length': 1.0, 'strike': 18.43494882292201, 'source': 857, 'target': 859},
#   {'length': 1.0, 'strike': 161.56505117707798, 'source': 858, 'target': 860},
#   {'length': 1.4142135623730951,
#    'strike': 18.43494882292201,
#    'source': 859,
#    'target': 861},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 860, 'target': 862},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 861, 'target': 863},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 862, 'target': 864},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 863, 'target': 865},
#   {'length': 1.0, 'strike': 0.0, 'source': 864, 'target': 866},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 865, 'target': 867},
#   {'length': 1.0, 'strike': 0.0, 'source': 866, 'target': 868},
#   {'length': 1.0, 'strike': 0.0, 'source': 867, 'target': 869},
#   {'length': 1.0, 'strike': 0.0, 'source': 868, 'target': 870},
#   {'length': 1.0, 'strike': 0.0, 'source': 869, 'target': 871},
#   {'length': 1.0, 'strike': 0.0, 'source': 870, 'target': 872},
#   {'length': 1.0, 'strike': 0.0, 'source': 871, 'target': 873},
#   {'length': 1.0, 'strike': 0.0, 'source': 872, 'target': 874},
#   {'length': 1.0, 'strike': 0.0, 'source': 874, 'target': 875},
#   {'length': 1.0, 'strike': 0.0, 'source': 875, 'target': 876},
#   {'length': 1.0, 'strike': 0.0, 'source': 876, 'target': 877},
#   {'length': 1.0, 'strike': 0.0, 'source': 877, 'target': 878},
#   {'length': 1.0, 'strike': 0.0, 'source': 878, 'target': 879},
#   {'length': 1.0, 'strike': 0.0, 'source': 879, 'target': 880},
#   {'length': 1.0, 'strike': 0.0, 'source': 880, 'target': 881},
#   {'length': 1.0, 'strike': 0.0, 'source': 881, 'target': 882},
#   {'length': 1.0, 'strike': 0.0, 'source': 882, 'target': 883},
#   {'length': 1.0, 'strike': 0.0, 'source': 883, 'target': 884},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 884, 'target': 885},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 885, 'target': 886},
#   {'length': 1.4142135623730951,
#    'strike': 18.43494882292201,
#    'source': 886,
#    'target': 887},
#   {'length': 1.0, 'strike': 18.43494882292201, 'source': 887, 'target': 888},
#   {'length': 1.4142135623730951,
#    'strike': 21.80140948635181,
#    'source': 888,
#    'target': 889},
#   {'length': 1.0, 'strike': 26.56505117707799, 'source': 889, 'target': 890},
#   {'length': 1.0, 'strike': 0.0, 'source': 891, 'target': 892},
#   {'length': 1.0, 'strike': 0.0, 'source': 892, 'target': 893},
#   {'length': 1.0, 'strike': 0.0, 'source': 893, 'target': 894},
#   {'length': 1.0, 'strike': 0.0, 'source': 894, 'target': 895},
#   {'length': 1.0, 'strike': 0.0, 'source': 895, 'target': 896},
#   {'length': 1.0, 'strike': 0.0, 'source': 896, 'target': 897},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 897, 'target': 898},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 898, 'target': 899},
#   {'length': 1.4142135623730951, 'strike': 0.0, 'source': 899, 'target': 900},
#   {'length': 1.0, 'strike': 0.0, 'source': 900, 'target': 901},
#   {'length': 1.4142135623730951, 'strike': 0.0, 'source': 901, 'target': 902},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 902, 'target': 903},
#   {'length': 1.0, 'strike': 0.0, 'source': 903, 'target': 904},
#   {'length': 1.4142135623730951, 'strike': 0.0, 'source': 904, 'target': 905},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 905, 'target': 906},
#   {'length': 1.0, 'strike': 161.56505117707798, 'source': 906, 'target': 907},
#   {'length': 1.0, 'strike': 161.56505117707798, 'source': 907, 'target': 908},
#   {'length': 1.4142135623730951,
#    'strike': 170.53767779197437,
#    'source': 908,
#    'target': 909},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 909, 'target': 910},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 910, 'target': 911},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 911, 'target': 912},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 912, 'target': 913},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 913, 'target': 914},
#   {'length': 1.4142135623730951,
#    'strike': 170.53767779197437,
#    'source': 914,
#    'target': 915},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 915, 'target': 916},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 916, 'target': 917},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 917, 'target': 918},
#   {'length': 1.0, 'strike': 0.0, 'source': 918, 'target': 919},
#   {'length': 1.0, 'strike': 0.0, 'source': 919, 'target': 920},
#   {'length': 1.0, 'strike': 0.0, 'source': 920, 'target': 921},
#   {'length': 1.0, 'strike': 0.0, 'source': 921, 'target': 922},
#   {'length': 1.0, 'strike': 0.0, 'source': 922, 'target': 923},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 923, 'target': 924},
#   {'length': 1.0, 'strike': 0.0, 'source': 924, 'target': 925},
#   {'length': 1.4142135623730951, 'strike': 0.0, 'source': 925, 'target': 926},
#   {'length': 1.4142135623730951,
#    'strike': 170.53767779197437,
#    'source': 926,
#    'target': 927},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 927, 'target': 928},
#   {'length': 1.4142135623730951,
#    'strike': 170.53767779197437,
#    'source': 928,
#    'target': 929},
#   {'length': 1.0, 'strike': 0.0, 'source': 929, 'target': 930},
#   {'length': 1.0, 'strike': 161.56505117707798, 'source': 930, 'target': 931},
#   {'length': 1.0, 'strike': 158.19859051364818, 'source': 931, 'target': 932},
#   {'length': 1.4142135623730951,
#    'strike': 165.96375653207355,
#    'source': 932,
#    'target': 933},
#   {'length': 1.0, 'strike': 0.0, 'source': 934, 'target': 935},
#   {'length': 1.0, 'strike': 0.0, 'source': 935, 'target': 936},
#   {'length': 1.0, 'strike': 0.0, 'source': 936, 'target': 937},
#   {'length': 1.0, 'strike': 0.0, 'source': 937, 'target': 938},
#   {'length': 1.0, 'strike': 0.0, 'source': 938, 'target': 939},
#   {'length': 1.0, 'strike': 0.0, 'source': 939, 'target': 940},
#   {'length': 1.0, 'strike': 0.0, 'source': 940, 'target': 941},
#   {'length': 1.0, 'strike': 0.0, 'source': 941, 'target': 942},
#   {'length': 1.0, 'strike': 0.0, 'source': 942, 'target': 943},
#   {'length': 1.0, 'strike': 0.0, 'source': 943, 'target': 944},
#   {'length': 1.0, 'strike': 0.0, 'source': 944, 'target': 945},
#   {'length': 1.0, 'strike': 0.0, 'source': 945, 'target': 946},
#   {'length': 1.0, 'strike': 0.0, 'source': 946, 'target': 947},
#   {'length': 1.0, 'strike': 0.0, 'source': 947, 'target': 948},
#   {'length': 1.0, 'strike': 0.0, 'source': 948, 'target': 949},
#   {'length': 1.0, 'strike': 0.0, 'source': 949, 'target': 950},
#   {'length': 1.0, 'strike': 0.0, 'source': 950, 'target': 951},
#   {'length': 1.0, 'strike': 0.0, 'source': 951, 'target': 952},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 952, 'target': 953},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 953, 'target': 954},
#   {'length': 1.4142135623730951,
#    'strike': 9.462322208025617,
#    'source': 954,
#    'target': 955},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 955, 'target': 956},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 956, 'target': 957},
#   {'length': 1.0, 'strike': 18.43494882292201, 'source': 957, 'target': 958},
#   {'length': 1.0, 'strike': 0.0, 'source': 958, 'target': 959},
#   {'length': 1.4142135623730951, 'strike': 0.0, 'source': 959, 'target': 960},
#   {'length': 1.4142135623730951, 'strike': 0.0, 'source': 960, 'target': 961},
#   {'length': 1.0, 'strike': 0.0, 'source': 961, 'target': 962},
#   {'length': 1.0, 'strike': 0.0, 'source': 962, 'target': 963},
#   {'length': 1.0, 'strike': 170.53767779197437, 'source': 963, 'target': 964},
#   {'length': 1.0, 'strike': 0.0, 'source': 964, 'target': 965},
#   {'length': 1.0, 'strike': 0.0, 'source': 965, 'target': 966},
#   {'length': 1.0, 'strike': 0.0, 'source': 966, 'target': 967},
#   {'length': 1.0, 'strike': 0.0, 'source': 967, 'target': 968},
#   {'length': 1.0, 'strike': 0.0, 'source': 968, 'target': 969},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 969, 'target': 970},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 970, 'target': 971},
#   {'length': 1.4142135623730951,
#    'strike': 9.462322208025617,
#    'source': 971,
#    'target': 972},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 972, 'target': 973},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 973, 'target': 974},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 974, 'target': 975},
#   {'length': 1.0, 'strike': 0.0, 'source': 975, 'target': 976},
#   {'length': 1.0, 'strike': 0.0, 'source': 976, 'target': 977},
#   {'length': 1.0, 'strike': 0.0, 'source': 977, 'target': 978},
#   {'length': 1.0, 'strike': 0.0, 'source': 978, 'target': 979},
#   {'length': 1.0, 'strike': 0.0, 'source': 979, 'target': 980},
#   {'length': 1.0, 'strike': 0.0, 'source': 980, 'target': 981},
#   {'length': 1.0, 'strike': 0.0, 'source': 981, 'target': 982},
#   {'length': 1.0, 'strike': 0.0, 'source': 982, 'target': 983},
#   {'length': 1.0, 'strike': 0.0, 'source': 983, 'target': 984},
#   {'length': 1.0, 'strike': 0.0, 'source': 984, 'target': 985},
#   {'length': 1.0, 'strike': 0.0, 'source': 985, 'target': 986},
#   {'length': 1.0, 'strike': 0.0, 'source': 986, 'target': 987},
#   {'length': 1.0, 'strike': 0.0, 'source': 987, 'target': 988},
#   {'length': 1.0, 'strike': 0.0, 'source': 988, 'target': 989},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 989, 'target': 990},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 990, 'target': 991},
#   {'length': 1.4142135623730951,
#    'strike': 9.462322208025617,
#    'source': 991,
#    'target': 992},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 992, 'target': 993},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 993, 'target': 994},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 994, 'target': 995},
#   {'length': 1.0, 'strike': 0.0, 'source': 995, 'target': 996},
#   {'length': 1.0, 'strike': 0.0, 'source': 996, 'target': 997},
#   {'length': 1.0, 'strike': 0.0, 'source': 997, 'target': 998},
#   {'length': 1.0, 'strike': 0.0, 'source': 998, 'target': 999},
#   {'length': 1.0, 'strike': 0.0, 'source': 999, 'target': 1000},
#   {'length': 1.0, 'strike': 0.0, 'source': 1000, 'target': 1001},
#   {'length': 1.0, 'strike': 0.0, 'source': 1001, 'target': 1002},
#   {'length': 1.0, 'strike': 0.0, 'source': 1002, 'target': 1003},
#   {'length': 1.0, 'strike': 0.0, 'source': 1003, 'target': 1004},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 1004, 'target': 1005},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 1005, 'target': 1006},
#   {'length': 1.4142135623730951,
#    'strike': 0.0,
#    'source': 1006,
#    'target': 1007},
#   {'length': 1.0, 'strike': 0.0, 'source': 1007, 'target': 1008},
#   {'length': 1.4142135623730951,
#    'strike': 0.0,
#    'source': 1008,
#    'target': 1009},
#   {'length': 1.0, 'strike': 0.0, 'source': 1009, 'target': 1010},
#   {'length': 1.0,
#    'strike': 170.53767779197437,
#    'source': 1010,
#    'target': 1011},
#   {'length': 1.0,
#    'strike': 170.53767779197437,
#    'source': 1011,
#    'target': 1012},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 1012, 'target': 1013},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 1013, 'target': 1014},
#   {'length': 1.4142135623730951,
#    'strike': 9.462322208025617,
#    'source': 1014,
#    'target': 1015},
#   {'length': 1.0, 'strike': 9.462322208025617, 'source': 1015, 'target': 1016},
#   ...]}

# %%
G_3d_15 = G

node = 0
for comp in tqdm(range(1,ret)):

    points = np.transpose(np.vstack((np.where(markers==comp))))    
    
    for point in points:
        G_3d_15.add_node(node)
        G_3d_15.nodes[node]['pos'] = (15, point[1], point[0])
        G_3d_15.nodes[node]['component'] = comp
        node += 1  

json_G_3d_15 = json_graph.node_link_data(G_3d_15)
# json_G_3d
# Out:
# 100%|██████████| 40/40 [00:00<00:00, 1052.60it/s]

# %% [markdown]
# # Plot 3D

# %%
from mpl_toolkits.mplot3d import Axes3D
from chart_studio import plotly
import plotly.offline as pyoff
import plotly.graph_objs as go

# %%
(json_G_3d_15).keys()
# Out:
# dict_keys(['directed', 'multigraph', 'graph', 'nodes', 'links'])

# %%
node_color, palette = get_node_colors(G_3d_15, 'component', return_palette=True)
pos = nx.get_node_attributes(G_3d_15, 'pos')

xi, yi, zi, c, s = [], [], [], [], []

for key, value in pos.items():
    xi.append(value[0])
    yi.append(value[1])
    zi.append(value[2])
    # print(type(colors[value]))
    # c.append(colors[key])
    s.append(20+20*G_3d_15.degree(key))

xi, yi, zi = np.array(xi), np.array(yi), np.array(zi)

# %%
len(xi), len(yi), len(zi)
# Out:
# (3232, 3232, 3232)

# %%
# %matplotlib widget
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,15))
ax = plt.axes(projection="3d")

# for i in range(len(xi)):
#     ax.plot3D([xi[i],xi[i+1]], [yi[i], yi[i+1]],[-1*zi[i], -1*zi[i+1]], 'blue', alpha=1)

ax.scatter(xi, yi,-1*zi, marker='o', c=node_color, edgecolors='w', alpha=0.5)
# Axes3D.plot(xs=xi, ys = yi, zs=-1*zi, c='black', alpha=0.5)
plt.show()

# %%
def network_plot_3D(G, angle, save=False):

    # Get node positions
    pos = nx.get_node_attributes(G, 'pos')
    
    # Get number of nodes
    n = G.number_of_nodes()

    # Get the maximum number of edges adjacent to a single node
    edge_max = max([G.degree(i) for i in range(n)])

    # Define color range proportional to number of edges adjacent to a single node
    colors = [plt.cm.plasma(G.degree(i)/edge_max) for i in range(n)] 

    # 3D network plot
    with plt.style.context(('ggplot')):
        
        fig = plt.figure(figsize=(10,7))
        ax = Axes3D(fig)
        
        # Loop on the pos dictionary to extract the x,y,z coordinates of each node
        for key, value in pos.items():
            xi = value[0]
            yi = value[1]
            zi = value[2]
            
        # Scatter plot
            ax.scatter(xi, yi, zi, c=colors[key], s=20+20*G.degree(key), edgecolors='k', alpha=0.7)
        
        # Loop on the list of edges to get the x,y,z, coordinates of the connected nodes
        # Those two points are the extrema of the line to be plotted
        for i,j in enumerate(G.edges()):

            x = np.array((pos[j[0]][0], pos[j[1]][0]))
            y = np.array((pos[j[0]][1], pos[j[1]][1]))
            z = np.array((pos[j[0]][2], pos[j[1]][2]))
        
        # Plot the connecting lines
            ax.plot(x, y, z, c='black', alpha=0.5)
    
    # Set the initial view
    ax.view_init(30, angle)

    # Hide the axes
    ax.set_axis_off()

    if save is not False:
        print('a')
        # plt.savefig(f""C:\scratch\\data\"+str{angle}.zfill{3}+".png"")
        # plt.close('all')
    else:
        plt.show()
    
    return
